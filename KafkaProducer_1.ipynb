# %%
pip install kafka-python
# Out:
# Collecting kafka-python
#   Downloading kafka_python-2.0.2-py2.py3-none-any.whl.metadata (7.8 kB)
# Downloading kafka_python-2.0.2-py2.py3-none-any.whl (246 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 246.5/246.5 kB 13.8 MB/s eta 0:00:00
# Installing collected packages: kafka-python
# Successfully installed kafka-python-2.0.2

# %%
import pandas as pd
from kafka import KafkaProducer
from time import sleep
from json import dumps
import json

# %%
producer = KafkaProducer(
    bootstrap_servers=['13.71.31.242:9092'], #change ip here
    value_serializer=lambda x: dumps(x).encode('utf-8')
    )

# %%
df = pd.read_csv("stock_data_new.csv")

# %%
df.head()
# Out:
#   Index         Date         Open         High          Low        Close  \
# 0   HSI  1986-DEC-31  2568.300049  2568.300049  2568.300049  2568.300049
# 1   HSI  1987-JAN-02  2540.100098  2540.100098  2540.100098  2540.100098
# 2   HSI  1987-JAN-05  2552.399902  2552.399902  2552.399902  2552.399902
# 3   HSI  1987-JAN-06  2583.899902  2583.899902  2583.899902  2583.899902
# 4   HSI  1987-JAN-07  2607.100098  2607.100098  2607.100098  2607.100098
#
#      Adj Close  Volume    CloseUSD
# 0  2568.300049     0.0  333.879006
# 1  2540.100098     0.0  330.213013
# 2  2552.399902     0.0  331.811987
# 3  2583.899902     0.0  335.906987
# 4  2607.100098     0.0  338.923013

# %%
df.sample(1).to_dict(orient="records")[0]
# Out:
# {'Index': 'IXIC',
#  'Date': '1971-APR-14',
#  'Open': 109.080002,
#  'High': 109.080002,
#  'Low': 109.080002,
#  'Close': 109.080002,
#  'Adj Close': 109.080002,
#  'Volume': 0.0,
#  'CloseUSD': 109.080002}

# %%
while True:
  dict_stock = df.sample(1).to_dict(orient="records")[0]
  producer.send('demo', value=dict_stock)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-6813c14e8ba9> in <cell line: 1>()
#       1 while True:
# ----> 2   dict_stock = df.sample(1).to_dict(orient="records")[0]
#       3   producer.send('demo', value=dict_stock)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in to_dict(self, orient, into, index)
#    2037         from pandas.core.methods.to_dict import to_dict
#    2038
# -> 2039         return to_dict(self, orient, into, index)
#    2040
#    2041     def to_gbq(
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/methods/to_dict.py in to_dict(df, orient, into, index)
#      98     box_native_indices = [
#      99         i
# --> 100         for i, col_dtype in enumerate(df.dtypes.values)
#     101         if col_dtype == np.dtype(object) or isinstance(col_dtype, ExtensionDtype)
#     102     ]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in dtypes(self)
#    6364         """
#    6365         data = self._mgr.get_dtypes()
# -> 6366         return self._constructor_sliced(data, index=self._info_axis, dtype=np.object_)
#    6367
#    6368     @final
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     429
#     430         if dtype is not None:
# --> 431             dtype = self._validate_dtype(dtype)
#     432
#     433         if data is None:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in _validate_dtype(cls, dtype)
#     490         """validate the passed dtype"""
#     491         if dtype is not None:
# --> 492             dtype = pandas_dtype(dtype)
#     493
#     494             # a compound dtype
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/dtypes/common.py in pandas_dtype(dtype)
#    1629     # raise a consistent TypeError if failed
#    1630     try:
# -> 1631         with warnings.catch_warnings():
#    1632             # GH#51523 - Series.astype(np.integer) doesn't show
#    1633             # numpy deprecation warning of np.integer
#
# /usr/lib/python3.10/warnings.py in __enter__(self)
#     456         return "%s(%s)" % (name, ", ".join(args))
#     457
# --> 458     def __enter__(self):
#     459         if self._entered:
#     460             raise RuntimeError("Cannot enter %r twice" % self)
#
# KeyboardInterrupt:
